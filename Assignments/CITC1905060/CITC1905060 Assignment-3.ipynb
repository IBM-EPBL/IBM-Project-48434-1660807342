# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1.Loading Dataset

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\91755\Downloads\abalone.csv")
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
print(df.describe())
print("--"*30)
print(df.info())
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df["Rings"].value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 26      1
# 29      1
# 25      1
# 1       1
# 2       1
# Name: Rings, dtype: int64

# %% [markdown]
# ### 2.Visualizations

# %% [markdown]
# #### Univariate Analysis

# %% [markdown]
# Distribution plot

# %%
sns.FacetGrid(df,hue="Rings",size=5).map(sns.histplot,"Diameter").add_legend()
# Out:
# C:\Users\91755\AppData\Roaming\Python\Python38\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue="Rings",size=5).map(sns.histplot,"Whole weight").add_legend()
# Out:
# C:\Users\91755\AppData\Roaming\Python\Python38\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Bivariate analysis:

# %% [markdown]
# Box plot:

# %%
sns.boxplot(x="Rings",y='Diameter',data=df)
plt.show()

# %%
sns.boxplot(x="Rings",y='Whole weight',data=df)
plt.show()

# %% [markdown]
# #### Multivariate Analysis:

# %% [markdown]
# Pair Plot:

# %%
sns.pairplot(df,aspect=.85,hue="Rings",height=3)
plt.show()

# %% [markdown]
# ### 3.Descriptive Statistics on  Dataset

# %%
mean = np.mean(df)

print("Mean = ", mean)
# Out:
# Mean =  Length            0.523992
# Diameter          0.407881
# Height            0.139516
# Whole weight      0.828742
# Shucked weight    0.359367
# Viscera weight    0.180594
# Shell weight      0.238831
# Rings             9.933684
# dtype: float64

# %%
from scipy import stats



# Mode
mode = stats.mode(df)
print("Mode = ", mode)
# Out:
# Mode =  ModeResult(mode=array([['M', 0.55, 0.45, 0.15, 0.2225, 0.175, 0.1715, 0.275, 9]],
#       dtype=object), count=array([[1528,   94,  139,  267,    8,   11,   15,   43,  689]]))

# %%
import numpy as np
# Median
df.median()
# Out:
# Length            0.5450
# Diameter          0.4250
# Height            0.1400
# Whole weight      0.7995
# Shucked weight    0.3360
# Viscera weight    0.1710
# Shell weight      0.2340
# Rings             9.0000
# dtype: float64

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
#correlations
plt.figure(figsize=(12,12))
sns.heatmap(df.drop('Rings',axis=1).corr(),cmap='GnBu',square=True);

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,square=True)
# Out:
# <AxesSubplot:>

# %%
#selecting the colums that are categorical
objList = df.select_dtypes(include = "object").columns
print (objList)
# Out:
# Index(['Sex'], dtype='object')

# %% [markdown]
# ### 7.Check For categorical column and encoding them.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in objList:
    df[i] = le.fit_transform(df[i].astype(str))

# %% [markdown]
# ### 5.Handling the missing values

# %%
for i in df:
    mean_value = df[i].mean()
    df[i].fillna(value=mean_value, inplace = True)
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# ### 6.Detection of Outliers

# %%
#looking for indexes that contain outlier in multiple columns
def detect_multiple_outlier(df,columns,index_list=[],threshold=1.5,cnt=1):
    """
    Returns outliers index based on Tukey's rule.
    """
    import collections
    for col in columns:
        desc=df[col].describe()
        
        q1=desc['25%']
        
        q3=desc['75%']
        IQR=q3-q1
        
        indexes=df[(df[col]<q1-threshold*IQR) |(df[col]>q3+threshold*IQR)].index
        index_list.extend(indexes)
 

        
    return([item for item, count in collections.Counter(index_list).items() if count > cnt])

# %%
#numeric columns
cols=list(df.columns)[1:]
outliers_=detect_multiple_outlier(df,cols,threshold=1.5,cnt=3)

# %%
len(outliers_),len(df)
# Out:
# (13, 4177)

# %%
df.median()
# Out:
# Sex               1.0000
# Length            0.5450
# Diameter          0.4250
# Height            0.1400
# Whole weight      0.7995
# Shucked weight    0.3360
# Viscera weight    0.1710
# Shell weight      0.2340
# Rings             9.0000
# dtype: float64

# %% [markdown]
# ### 8.Splitting data into dependent and independent variables.

# %%
# independent varibles-X

X=df.drop(columns=['Rings'],axis=1)
X.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight
# 0          0.1010         0.150
# 1          0.0485         0.070
# 2          0.1415         0.210
# 3          0.1140         0.155
# 4          0.0395         0.055

# %%
# y target-dependent variable


y=df.Rings
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %% [markdown]
# ### 9.Scaling the dependent and independent variables

# %%
from sklearn.preprocessing import scale
import pandas as pd

X_scaled=pd.DataFrame(scale(X),columns=X.columns)
X_scaled.head()
# Out:
#         Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0  1.151980 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685
# 1  1.151980 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910
# 2 -1.280690  0.050033  0.122130 -0.107991     -0.309469       -0.463500
# 3  1.151980 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238
# 4 -0.064355 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968
#
#    Viscera weight  Shell weight
# 0       -0.726212     -0.638217
# 1       -1.205221     -1.212987
# 2       -0.356690     -0.207139
# 3       -0.607600     -0.602294
# 4       -1.287337     -1.320757

# %% [markdown]
# ### 10.Splitting the data into the training and testing.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X_scaled,y, test_size=0.3,random_state=0)

# %%
X_train
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 1376  1.151980  0.799543  1.029133  0.848442      0.923373        0.955826
# 1225 -0.064355 -1.490625 -1.540707 -1.303532     -1.281263       -1.146128
# 2722 -0.064355 -1.240789 -1.339151 -1.064424     -1.222119       -1.191186
# 3387  1.151980  0.174951  0.021352  0.131117      0.090261       -0.251727
# 2773 -1.280690  0.466427  0.575631  0.131117      0.321738        0.498488
# ...        ...       ...       ...       ...           ...             ...
# 1033  1.151980  1.049379  1.180300  1.087551      1.617803        1.374865
# 3264 -1.280690  1.091018  0.928354  0.011563      0.696995        0.816146
# 1653  1.151980  0.591345  0.424464  0.131117      0.265653        0.466947
# 2607 -1.280690  0.841182  0.827576  0.609334      0.608279        0.530028
# 2732 -0.064355 -0.949313 -0.835261 -0.705762     -1.025313       -1.022219
#
#       Viscera weight  Shell weight
# ...

# %%
y_train
# Out:
# 1376    10
# 1225     5
# 2722     7
# 3387    18
# 2773    11
#         ..
# 1033    10
# 3264    12
# 1653    10
# 2607     9
# 2732     8
# Name: Rings, Length: 2923, dtype: int64

# %%
X_train.shape,y_train.shape
# Out:
# ((2923, 8), (2923,))

# %%
X_test
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 668   1.151980  0.216591  0.172519  0.370226      0.181016       -0.368878
# 1580 -0.064355 -0.199803 -0.079426 -0.466653     -0.433875       -0.443224
# 3784  1.151980  0.799543  0.726798  0.370226      0.870348        0.755318
# 463  -0.064355 -2.531611 -2.447709 -2.020857     -1.579022       -1.522362
# 2615  1.151980  1.007740  0.928354  0.848442      1.390405        1.415417
# ...        ...       ...       ...       ...           ...             ...
# 1052  1.151980  2.007086  1.936135  1.924430      3.004623        2.918100
# 3439 -0.064355 -0.699476 -0.583316 -0.347099     -0.760186       -0.673019
# 1174 -1.280690  0.924461  0.877965 -2.977291      0.668443        0.685478
# 2210  1.151980  1.132658  0.978743  1.446213      1.635138        0.572833
# 2408 -0.064355  0.799543  0.777187  0.728888      0.773474        0.545798
#
#       Viscera weight  Shell weight
# ...

# %%
y_test
# Out:
# 668     13
# 1580     8
# 3784    11
# 463      5
# 2615    12
#         ..
# 1052    12
# 3439     8
# 1174     9
# 2210    18
# 2408    15
# Name: Rings, Length: 1254, dtype: int64

# %%
X_test.shape , y_test.shape
# Out:
# ((1254, 8), (1254,))

# %%
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
  
# Splitting the data into training and testing data
regr = LinearRegression()
  
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.5140139913856603

# %%
y_pred = regr.predict(X_test)
print(y_pred)
# Out:
# [13.11640829  9.65691091 10.35350972 ...  9.00574144 18.83125845
#  11.76923257]

# %%
print(y_test)
# Out:
# 668     13
# 1580     8
# 3784    11
# 463      5
# 2615    12
#         ..
# 1052    12
# 3439     8
# 1174     9
# 2210    18
# 2408    15
# Name: Rings, Length: 1254, dtype: int64

# %%
df = pd.DataFrame(list(zip(y_test, y_pred)),
               columns =['Actual value', 'Predicted Value'])

# %%
df
# Out:
#       Actual value  Predicted Value
# 0               13        13.116408
# 1                8         9.656911
# 2               11        10.353510
# 3                5         5.636487
# 4               12        10.674365
# ...            ...              ...
# 1249            12        13.746148
# 1250             8         8.530551
# 1251             9         9.005741
# 1252            18        18.831258
# 1253            15        11.769233
#
# [1254 rows x 2 columns]

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'Mean absolute error: {mae:.2f}')
print(f'Mean squared error: {mse:.2f}')
print(f'Root mean squared error: {rmse:.2f}')
# Out:
# Mean absolute error: 1.61
# Mean squared error: 5.12
# Root mean squared error: 2.26
